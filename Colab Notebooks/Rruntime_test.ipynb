# %%
library(ggplot2)

# %%
x = c(2,5,6,-1,5)

# %%
y = c(10,17,11,12,21)

# %%
x = matrix(x)

# %%
mod = lm(y~x)

# %%
summary(mod)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#       1       2       3       4       5
# -3.2470  1.7108 -4.9699  0.7952  5.7108
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  11.8855     3.6125   3.290   0.0461 *
# x             0.6807     0.8468   0.804   0.4803
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.879 on 3 degrees of freedom
# Multiple R-squared:  0.1772,	Adjusted R-squared:  -0.09701
# F-statistic: 0.6463 on 1 and 3 DF,  p-value: 0.4803
